# %% [markdown]
# # Data Preperation
#
# **You have 12 datasets : ecg, pcg (2) * balanced/ imbalalanced (2) * train/ val/ test (3) =12**
#
# use ctrl + F:
#
#
#
# 1.**/*ecg/ <->/*pcg/** and **dataset_path -> path_ecg/ path_pcg**
#
# 2.**balanced -> imbalanced**
#
# ### Note that, we have to manually change the created directories to /balanced, /balanced directories and rename those

# %%
from intelliscope import SelectDataset

path_pcg,path_ecg = SelectDataset(0)

data_path=path_pcg
# Out:
# Loading... >  ICASSP_01
# 	=> /home/ubuntu/intelliscope/datasets/PhysioNet2016/preprocessed/training-a/original/ecg/01-cmor1.5-1.0/
# 	=> /home/ubuntu/intelliscope/datasets/PhysioNet2016/preprocessed/training-a/original/pcg/01-morl/

# %%
import os
import shutil

# %%
# !rm -rf /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced

# !ls /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced

# %%
# !rm -rf /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val 
# !rm -rf /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train 
# !rm -rf /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test

# %%
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val 
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test 
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train 

namesA=[]

for img in os.listdir(data_path):
    if img[-4:]=='tiff' and img[0]=='a':
        namesA.append(img)
        
namesA.sort()
#namesA=balanced(namesA)
length=len(namesA)
for img in namesA[:int(length*0.15)]:
    shutil.copy(data_path+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/'+img)
for img in namesA[int(length*0.15):int(length*0.3)]:
    shutil.copy(data_path+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/'+img)
for img in namesA[int(length*0.3):]:
    shutil.copy(data_path+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/'+img)

# %%
len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/'))
# Out:
# 2448

# %%
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/0
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1

# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/0
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1

# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/0
# !mkdir /home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1

# %%
for img in os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train'):
    if 'tiff' in img:
        if img[-6]=='A':
            shutil.move('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/'+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1/'+img)
        elif img[-6]=='N':
            shutil.move('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/'+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/0/'+img)

# %%
for img in os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val'):
    if 'tiff' in img:
        if img[-6]=='A':
            shutil.move('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/'+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1/'+img)
        elif img[-6]=='N':
            shutil.move('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/'+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/0/'+img)

# %%
for img in os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test'):
    if 'tiff' in img:
        if img[-6]=='A':
            shutil.move('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/'+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1/'+img)
        elif img[-6]=='N':
            shutil.move('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/'+img,'/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/0/'+img)

# %%
# !ls '/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val'
# Out:
# 0  1

# %%
n1=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/0'))
n2=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1'))

n3=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/0'))
n4=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1'))

n5=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/0'))
n6=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1'))

# %%
n1, n2, n3, n4, n5, n6
# Out:
# (700, 1748, 145, 379, 157, 367)

# %%
import matplotlib.pyplot as plt
img1=plt.imread('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/0/'+os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/0')[10])
img2=plt.imread('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1/'+os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1')[10])

img3=plt.imread('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/0/'+os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/0')[10])
img4=plt.imread('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1/'+os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1')[10])

img5=plt.imread('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/0/'+os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/0')[10])
img6=plt.imread('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1/'+os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1')[10])

plt.figure(figsize=(25, 10))
plt.subplot(2,3,1)
plt.imshow(img1)
plt.subplot(2,3,2)
plt.imshow(img2)
plt.subplot(2,3,3)
plt.imshow(img3)
plt.subplot(2,3,4)
plt.imshow(img4)
plt.subplot(2,3,5)
plt.imshow(img5)
plt.subplot(2,3,6)
plt.imshow(img6)

# %% [markdown]
# # Stop here for imbalanced data generation

# %%
import numpy as np
new_train_1=np.random.choice(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1'), n1, replace=False)
new_val_1=np.random.choice(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1'), n3, replace=False)
new_test_1=np.random.choice(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1'), n5, replace=False)

# %%
for img in os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1'):
    if img in new_train_1:pass
    else:os.remove('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1/'+img)

# %%
for img in os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1'):
    if img in new_val_1:pass
    else:os.remove('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1/'+img)

# %%
for img in os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1'):
    if img in new_test_1:pass
    else:os.remove('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1/'+img)

# %%
n1=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/0'))
n2=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/train/1'))

n3=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/0'))
n4=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/val/1'))

n5=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/0'))
n6=len(os.listdir('/home/ubuntu/intelliscope/notebooks/physionet2016/pcg_ecg/Udith/datasetsA/pcg/balanced/test/1'))

# %%
n1, n2, n3, n4, n5, n6
# Out:
# (700, 700, 145, 145, 157, 157)
